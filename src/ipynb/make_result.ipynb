# %%
import io, os, json, random, copy
import distutils.dir_util
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from collections import Counter
from tqdm import tqdm
import glob

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
import os
os.chdir('/content/gdrive/My Drive/Google Colaboratory/kakao_arena/kakao_arena_melon')  #/src/ipynb')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
def load_json(fname):
    try:
        with open(fname, encoding="utf-8") as f:
            json_obj = json.load(f)
    except:
        with open(fname, encoding="utf-16") as f:
            json_obj = json.load(f)
    return json_obj

def write_json(data, fname):
    def _conv(o):
        if isinstance(o, (np.int64, np.int32)):
            return int(o)
        raise TypeError
    parent = os.path.dirname(fname)
    distutils.dir_util.mkpath(parent)
    try:
        with io.open(fname, "w", encoding="utf-8") as f:
            json_str = json.dumps(data, ensure_ascii=False, default=_conv)
            f.write(json_str)
    except:
        with io.open(fname, "w", encoding="utf-16") as f:
            json_str = json.dumps(data, ensure_ascii=False, default=_conv)
            f.write(json_str)

def make_result(data_path, save_path):
    csvfiles, result = [], []
    for file in glob.glob(data_path):
        csvfiles.append(file)
    for i in csvfiles:
        print(i)
        result.extend(load_json(i))
    if len(result)==23015:
        write_json(result, save_path)
        print('file saved')
    else:
        print('len of result is not 23015 : {}'.format(len(result)))

# %%
make_result("data/results/val/*.json", "data/results/val/results.json")
# Out:
# data/results/val/val3_16_predict.json
# data/results/val/val3_15_predict.json
# data/results/val/val3_0_12_predict.json
# data/results/val/val3_13_14_predict.json
# data/results/val/val1_13_14_predict(my_baselinev1_v16).json
# data/results/val/val1_15_16_predict(my_baselinev1_v17).json
# data/results/val/val1_11_12_predict(my_baselinev1_v15).json
# data/results/val/val1_0_10_predict(my_baselinev1_v14).json
# data/results/val/val4_predict_withTitle.json
# data/results/val/val2_predict_withTitle.json
# file saved
