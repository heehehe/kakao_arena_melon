# %% [markdown]
# <a href="https://colab.research.google.com/github/heehehe/kakao_arena_melon/blob/master/modeling_by_title" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###패키지 import & data 불러오기

# %%
# !git clone https://github.com/kakao/khaiii.git
# !pip install cmake
# !mkdir build
# !cd build && cmake /content/khaiii
# !cd /content/build/ && make all
# !cd /content/build/ && make resource
# !cd /content/build && make install
# !cd /content/build && make package_python
# !pip install /content/build/package_python

# %%
### colab 사용 시 실행
from google.colab import drive
drive.mount('/content/gdrive/')
import os
os.chdir('gdrive/My Drive/Google Colaboratory/kakao_arena/kakao_arena_melon')  #/src/ipynb')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import sys
from src.basic_utils import *

import re
from khaiii import KhaiiiApi
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
data_path = 'data/'

train = pd.read_parquet(data_path+'train(song_trim).parquet')
val = pd.read_json(data_path+'val(lower).json')
test = pd.read_json(data_path+'test(lower).json')
song_meta = load_json(data_path+'song_meta.json')
# genre_gn_all = pd.read_json(data_path+'genre_gn_all.json', typ = 'series')

### make_file.ipynb 내에서 만들어진 tag_song_dict / song_tag_dict 불러오기
tag_song_dict = load_json(data_path+'tag_song_dict.json')
song_tag_dict = load_json(data_path+'song_tag_dict.json')

# %%
train.head(2)
# Out:
#        tags     id  ... like_cnt                updt_date
# 0       [락]  61281  ...       71  2013-12-19 18:36:19.000
# 1  [추억, 회상]  10532  ...        1  2014-12-02 16:19:42.000
#
# [2 rows x 6 columns]

# %% [markdown]
# ### 제목에서 가수 추출

# %%
artist_list = []
for sm in song_meta:
    artist_list.extend(sm['artist_name_basket'])
artist_list = list(set(artist_list))

# %%
len(artist_list)
# Out:
# 111304

# %%
# 과도한 for문으로 너무 오래걸려서 fail

tags_artist_list = [[]]*len(train)

for i in tqdm(range(len(train))):
    for artist in artist_list:
        if train.iloc[i]['plylst_title'].find(artist) != -1:
            tags_artist_list[i].append(artist)

# %% [markdown]
# #### tag 형태소 분석

# %%
print('train에서 title 존재 데이터 개수 : {}개 ({}%)'.format(len(train[train['plylst_title']!='']), len(train[train['plylst_title']!=''])/len(train)*100))
print('val에서 title 존재 데이터 개수   : {}개 ({}%)'.format(len(val[val['plylst_title']!='']),     len(val[val['plylst_title']!=''])/len(val)*100))
print('test에서 title 존재 데이터 개수  : {}개 ({}%)'.format(len(test[test['plylst_title']!='']),   len(test[test['plylst_title']!=''])/len(test)*100))
# Out:
# train에서 title 존재 데이터 개수 : 115071개 (100.0%)
# val에서 title 존재 데이터 개수   : 4373개 (19.00065174885944%)
# test에서 title 존재 데이터 개수  : 2041개 (19.00372439478585%)

# %%
def flatten(df_col):
    # nested list 풀기
    list_of_list = df_col.values.tolist()
    flatten = [j for i in list_of_list for j in i]
    return flatten

def do_khaiii(data):
    api = KhaiiiApi()
    morphs_prep = []
    for d in data:
        try:
            for word in api.analyze(d):
                for w in word.morphs:
                    if len(w.lex) > 1 or w.tag not in ['ETM','ETN','XSA','JX','VV']:
                        morphs_prep.append((w.lex, w.tag))
        except:
            pass # 비어있는 경우
    gc.collect()
    return morphs_prep

def do_khaiii_col(data):
    api = KhaiiiApi()
    morphs_prep = ['']*len(data)
    for i,d in enumerate(data):
        try:
            for word in api.analyze(d):
                for w in word.morphs:
                    if len(w.lex) > 1 or w.tag not in ['ETM','ETN','XSA','JX','VV']:
                        morphs_prep[i] = (w.lex, w.tag)
        except:
            pass # 비어있는 경우
    gc.collect()
    return morphs_prep

# %%
d='크리스마스캐롤'
for word in api.analyze(d):
    print(word)
    # for w in word.morphs:
# Out:
# 크리스마스캐롤	크리스마스캐롤/NNG

# %%
tags_list = flatten(train['tags'])
songs_list = flatten(train['songs'])

# %%
print(len(tags_list))
print(len(songs_list))
# Out:
# 476331
# 5285871

# %%
tag_morphs = []
for tag in tqdm(tags_list):
    tag_morphs.extend(do_khaiii(tag))

# %%
len(tag_morphs)
# Out:
# 722860

# %%
# Counter([t[0] for t in tag_morphs]).most_common()
Counter(tag_morphs).most_common()[:30]
# Out:
# [(('ㄴ', 'ETM'), 26970),
#  (('하', 'XSA'), 21926),
#  (('기분', 'NNG'), 17443),
#  (('전환', 'NNG'), 16543),
#  (('감성', 'NNG'), 14411),
#  (('휴식', 'NNG'), 11385),
#  (('발라드', 'NNG'), 10798),
#  (('잔잔', 'XR'), 10526),
#  (('드라이브', 'NNG'), 10212),
#  (('힐링', 'NNG'), 9871),
#  (('새벽', 'NNG'), 9422),
#  (('사랑', 'NNG'), 9418),
#  (('힙합', 'NNG'), 8983),
#  (('밤', 'NNG'), 8765),
#  (('음악', 'NNG'), 8649),
#  (('는', 'JX'), 8462),
#  (('카페', 'NNG'), 7776),
#  (('팝', 'NNG'), 7373),
#  (('추억', 'NNG'), 6841),
#  (('ㅁ', 'ETN'), 6388),
#  (('매장', 'NNG'), 6124),
#  (('인디', 'NNG'), 5594),
#  (('이별', 'NNG'), 5505),
#  (('설', 'NNP'), 5090),
#  (('나', 'VV'), 5027),
#  (('신', 'NNG'), 4988),
#  (('레', 'VV'), 4912),
#  (('여행', 'NNG'), 4857),
#  (('회상', 'NNG'), 4736),
#  (('겨울', 'NNG'), 4727)]

# %%
tag_morphs_counter = Counter([t[1] for t in tag_morphs]).most_common()
tag_morphs_list = [t[0] for t in tag_morphs_counter]
tag_morphs_cnt = [t[1] for t in tag_morphs_counter]

plt.figure(figsize=(8,8))
plt.barh(tag_morphs_list[::-1], tag_morphs_cnt[::-1])
plt.show()

# %%
tag_morphs_counter

# %%
api = KhaiiiApi()

tag_morphs_prep = []
for tag in train['tags']:
    for t in tag:
        try:
            for word in api.analyze(t):
                for w in word.morphs:
                    if len(w.lex) > 1 or w.tag not in ['ETM','ETN','XSA','JX','VV']:
                        tag_morphs_prep.append((w.lex, w.tag))
        except:
            pass # 비어있는 경우

# %%
len(tag_morphs_prep)
# Out:
# 623244

# %%
Counter(tag_morphs_prep).most_common()[:30]
# Out:
# [(('기분', 'NNG'), 17443),
#  (('전환', 'NNG'), 16543),
#  (('감성', 'NNG'), 14411),
#  (('휴식', 'NNG'), 11385),
#  (('발라드', 'NNG'), 10798),
#  (('잔잔', 'XR'), 10526),
#  (('드라이브', 'NNG'), 10212),
#  (('힐링', 'NNG'), 9871),
#  (('새벽', 'NNG'), 9422),
#  (('사랑', 'NNG'), 9418),
#  (('힙합', 'NNG'), 8983),
#  (('밤', 'NNG'), 8765),
#  (('음악', 'NNG'), 8649),
#  (('카페', 'NNG'), 7776),
#  (('팝', 'NNG'), 7373),
#  (('추억', 'NNG'), 6841),
#  (('매장', 'NNG'), 6124),
#  (('인디', 'NNG'), 5594),
#  (('이별', 'NNG'), 5505),
#  (('설', 'NNP'), 5090),
#  (('신', 'NNG'), 4988),
#  (('여행', 'NNG'), 4857),
#  (('회상', 'NNG'), 4736),
#  (('겨울', 'NNG'), 4727),
#  (('여름', 'NNG'), 4358),
#  (('가을', 'NNG'), 4169),
#  (('비', 'NNG'), 4166),
#  (('스트레스', 'NNG'), 4163),
#  (('노래', 'NNG'), 4077),
#  (('락', 'MAG'), 4026)]

# %%
tag_morphs_counter = Counter([t[1] for t in tag_morphs_prep]).most_common()
tag_morphs_list = [t[0] for t in tag_morphs_counter]
tag_morphs_cnt = [t[1] for t in tag_morphs_counter]

plt.figure(figsize=(8,8))
plt.barh(tag_morphs_list[::-1], tag_morphs_cnt[::-1])
plt.show()

# %%
tag_morphs_counter
# Out:
# [('NNG', 441528),
#  ('NNP', 55476),
#  ('SL', 31299),
#  ('XR', 19608),
#  ('MAG', 12875),
#  ('EC', 8372),
#  ('VA', 8109),
#  ('SN', 7700),
#  ('XSN', 5605),
#  ('JKB', 4754),
#  ('NNB', 3702),
#  ('VV', 3687),
#  ('SS', 3369),
#  ('VCP', 3337),
#  ('JKS', 2194),
#  ('VX', 2095),
#  ('XSV', 1921),
#  ('NP', 1568),
#  ('JKO', 989),
#  ('JKG', 945),
#  ('MM', 904),
#  ('IC', 853),
#  ('XPN', 664),
#  ('EP', 530),
#  ('JC', 401),
#  ('NR', 193),
#  ('JX', 138),
#  ('SH', 99),
#  ('XSA', 89),
#  ('SW', 66),
#  ('MAJ', 41),
#  ('VCN', 23),
#  ('JKV', 21),
#  ('ETM', 17),
#  ('ZZ', 16),
#  ('SO', 14),
#  ('EF', 12),
#  ('SE', 11),
#  ('JKC', 10),
#  ('SP', 6),
#  ('ZV', 3)]

# %% [markdown]
# #### train에서 title로 태그 추출

# %%
api = KhaiiiApi()

def do_khaiii_col(data):
    morphs_prep = ['']*len(data)
    for i,d in enumerate(tqdm(data)):
        list_add = []
        try:
            for word in api.analyze(d):
                for w in word.morphs:
                    # if w.tag in ['NNG','NNP','SL','XR']:
                    # if (len(w.lex) > 1 or w.tag not in ['ETM','ETN','JX','VV','VA','VCP']) \
                    if len(w.lex) > 1\
                       and w.tag not in ['NP','JKS','JKC','JKG','JKO','JKB','JKV','JKQ','JX','JC',\
                                         'EP','EF','EC','SF','SP','SS','SE','SO','XSA','VV','VA']\
                       and w.lex not in ['ㅋ','노래','음악','곡','월']:
                        list_add.append((w.lex, w.tag))
        except:
            pass # 비어있는 경우
        morphs_prep[i] = list_add
    gc.collect()
    return morphs_prep

# %%
title_khaiii = do_khaiii_col(train['plylst_title'].str.replace("[^0-9a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣 ]","")) #A-Za-z
# Out:
#   0%|          | 0/115071 [00:00<?, ?it/s]
#
#   0%|          | 145/115071 [00:00<01:19, 1449.51it/s]
#
#   0%|          | 301/115071 [00:00<01:17, 1478.62it/s]
#
#   0%|          | 457/115071 [00:00<01:16, 1498.95it/s]
#
#   1%|          | 598/115071 [00:00<01:17, 1470.48it/s]
#
#   1%|          | 758/115071 [00:00<01:15, 1505.19it/s]
#
#   1%|          | 916/115071 [00:00<01:14, 1525.31it/s]
#
#   1%|          | 1069/115071 [00:00<01:14, 1526.61it/s]
#
#   1%|          | 1231/115071 [00:00<01:13, 1552.62it/s]
#
#   1%|          | 1379/115071 [00:00<01:14, 1516.53it/s]
#
#   1%|▏         | 1538/115071 [00:01<01:14, 1534.05it/s]
#
#   1%|▏         | 1700/115071 [00:01<01:12, 1555.93it/s]
#
#   2%|▏         | 1854/115071 [00:01<01:13, 1548.29it/s]
#
#   2%|▏         | 2011/115071 [00:01<01:12, 1554.74it/s]
#
#   2%|▏         | 2166/115071 [00:01<01:14, 1523.42it/s]
#
#   2%|▏         | 2329/115071 [00:01<01:12, 1551.91it/s]
#
#   2%|▏         | 2488/115071 [00:01<01:12, 1560.63it/s]
#
#   2%|▏         | 2644/115071 [00:01<01:13, 1522.71it/s]
#
#   2%|▏         | 2797/115071 [00:01<01:14, 1516.65it/s]
#
#   3%|▎         | 2957/115071 [00:01<01:12, 1536.75it/s]
#
#   3%|▎         | 3111/115071 [00:02<01:13, 1531.36it/s]
#
#   3%|▎         | 3269/115071 [00:02<01:12, 1544.01it/s]
#
#   3%|▎         | 3429/115071 [00:02<01:11, 1556.91it/s]
#
#   3%|▎         | 3585/115071 [00:02<01:11, 1556.44it/s]
#
#   3%|▎         | 3741/115071 [00:02<01:14, 1496.62it/s]
#
#   3%|▎         | 3903/115071 [00:02<01:12, 1530.65it/s]
#
#   4%|▎         | 4057/115071 [00:02<01:12, 1531.86it/s]
#
#   4%|▎         | 4216/115071 [00:02<01:11, 1548.29it/s]
#
#   4%|▍         | 4372/115071 [00:02<01:12, 1522.02it/s]
#
#   4%|▍         | 4533/115071 [00:02<01:11, 1545.44it/s]
#
#   4%|▍         | 4696/115071 [00:03<01:10, 1566.65it/s]
#
#   4%|▍         | 4853/115071 [00:03<01:11, 1548.09it/s]
#
#   4%|▍         | 5010/115071 [00:03<01:10, 1553.27it/s]
#
#   4%|▍         | 5174/115071 [00:03<01:09, 1577.10it/s]
#
#   5%|▍         | 5332/115071 [00:03<01:10, 1549.40it/s]
#
#   5%|▍         | 5497/115071 [00:03<01:09, 1577.61it/s]
#
#   5%|▍         | 5663/115071 [00:03<01:08, 1600.19it/s]
#
#   5%|▌         | 5827/115071 [00:03<01:07, 1610.63it/s]
#
#   5%|▌         | 5989/115071 [00:03<01:09, 1579.98it/s]
#
#   5%|▌         | 6148/115071 [00:03<01:09, 1574.61it/s]
#
#   5%|▌         | 6306/115071 [00:04<01:09, 1571.68it/s]
#
#   6%|▌         | 6464/115071 [00:04<01:10, 1535.22it/s]
#
#   6%|▌         | 6628/115071 [00:04<01:09, 1562.85it/s]
#
#   6%|▌         | 6786/115071 [00:04<01:09, 1565.07it/s]
#
#   6%|▌         | 6943/115071 [00:04<01:10, 1532.65it/s]
#
#   6%|▌         | 7098/115071 [00:04<01:10, 1536.59it/s]
#
#   6%|▋         | 7261/115071 [00:04<01:09, 1561.15it/s]
#
#   6%|▋         | 7419/115071 [00:04<01:08, 1565.89it/s]
#
#   7%|▋         | 7582/115071 [00:04<01:07, 1582.26it/s]
#
#   7%|▋         | 7741/115071 [00:04<01:08, 1562.66it/s]
#
#   7%|▋         | 7906/115071 [00:05<01:07, 1586.08it/s]
#
#   7%|▋         | 8070/115071 [00:05<01:06, 1597.97it/s]
#
#   7%|▋         | 8230/115071 [00:05<01:07, 1583.55it/s]
#
#   7%|▋         | 8389/115071 [00:05<01:08, 1562.70it/s]
#
#   7%|▋         | 8546/115071 [00:05<01:09, 1527.26it/s]
#
#   8%|▊         | 8700/115071 [00:05<01:10, 1501.88it/s]
#
#   8%|▊         | 8851/115071 [00:05<01:11, 1480.07it/s]
#
#   8%|▊         | 9004/115071 [00:05<01:10, 1494.22it/s]
#
#   8%|▊         | 9154/115071 [00:05<01:11, 1479.69it/s]
#
#   8%|▊         | 9310/115071 [00:06<01:10, 1501.84it/s]
#
#   8%|▊         | 9464/115071 [00:06<01:09, 1510.73it/s]
#
#   8%|▊         | 9616/115071 [00:06<01:10, 1490.74it/s]
#
#   8%|▊         | 9773/115071 [00:06<01:09, 1512.32it/s]
#
#   9%|▊         | 9926/115071 [00:06<01:09, 1516.88it/s]
#
#   9%|▉         | 10078/115071 [00:06<01:10, 1484.99it/s]
#
#   9%|▉         | 10246/115071 [00:06<01:08, 1537.39it/s]
#
#   9%|▉         | 10406/115071 [00:06<01:07, 1555.32it/s]
#
#   9%|▉         | 10563/115071 [00:06<01:08, 1526.86it/s]
#
#   9%|▉         | 10721/115071 [00:06<01:07, 1539.41it/s]
#
#   9%|▉         | 10887/115071 [00:07<01:06, 1571.48it/s]
#
#  10%|▉         | 11045/115071 [00:07<01:06, 1560.79it/s]
#
#  10%|▉         | 11211/115071 [00:07<01:05, 1588.50it/s]
#
#  10%|▉         | 11377/115071 [00:07<01:04, 1604.88it/s]
#
#  10%|█         | 11538/115071 [00:07<01:05, 1576.16it/s]
#
#  10%|█         | 11696/115071 [00:07<01:13, 1411.85it/s]
#
#  10%|█         | 11846/115071 [00:07<01:12, 1433.64it/s]
#
#  10%|█         | 12000/115071 [00:07<01:10, 1462.52it/s]
#
#  11%|█         | 12161/115071 [00:07<01:08, 1500.77it/s]
#
#  11%|█         | 12313/115071 [00:08<01:08, 1500.92it/s]
#
#  11%|█         | 12465/115071 [00:08<01:08, 1505.59it/s]
#
#  11%|█         | 12623/115071 [00:08<01:07, 1526.49it/s]
#
#  11%|█         | 12777/115071 [00:08<01:07, 1526.37it/s]
#
#  11%|█         | 12945/115071 [00:08<01:05, 1568.92it/s]
#
#  11%|█▏        | 13103/115071 [00:08<01:05, 1552.30it/s]
#
#  12%|█▏        | 13259/115071 [00:08<01:05, 1544.99it/s]
#
#  12%|█▏        | 13417/115071 [00:08<01:05, 1554.56it/s]
#
#  12%|█▏        | 13581/115071 [00:08<01:04, 1578.96it/s]
#
#  12%|█▏        | 13752/115071 [00:08<01:02, 1614.33it/s]
#
#  12%|█▏        | 13914/115071 [00:09<01:03, 1590.83it/s]
#
#  12%|█▏        | 14074/115071 [00:09<01:03, 1580.72it/s]
#
#  12%|█▏        | 14233/115071 [00:09<01:03, 1582.45it/s]
#
#  13%|█▎        | 14397/115071 [00:09<01:02, 1598.47it/s]
#
#  13%|█▎        | 14558/115071 [00:09<01:03, 1588.12it/s]
#
#  13%|█▎        | 14717/115071 [00:09<01:03, 1586.61it/s]
#
#  13%|█▎        | 14876/115071 [00:09<01:03, 1566.68it/s]
#
#  13%|█▎        | 15035/115071 [00:09<01:03, 1572.67it/s]
#
#  13%|█▎        | 15197/115071 [00:09<01:03, 1584.19it/s]
#
#  13%|█▎        | 15366/115071 [00:09<01:01, 1612.99it/s]
#
#  13%|█▎        | 15528/115071 [00:10<01:02, 1586.55it/s]
#
#  14%|█▎        | 15691/115071 [00:10<01:02, 1596.80it/s]
#
#  14%|█▍        | 15851/115071 [00:10<01:02, 1597.23it/s]
#
#  14%|█▍        | 16011/115071 [00:10<01:02, 1597.51it/s]
#
#  14%|█▍        | 16181/115071 [00:10<01:00, 1626.43it/s]
#
#  14%|█▍        | 16344/115071 [00:10<01:01, 1618.26it/s]
#
#  14%|█▍        | 16506/115071 [00:10<01:02, 1588.90it/s]
#
#  14%|█▍        | 16667/115071 [00:10<01:01, 1593.94it/s]
#
#  15%|█▍        | 16827/115071 [00:10<01:02, 1577.31it/s]
#
#  15%|█▍        | 16985/115071 [00:10<01:02, 1572.72it/s]
#
#  15%|█▍        | 17149/115071 [00:11<01:01, 1585.10it/s]
#
#  15%|█▌        | 17320/115071 [00:11<01:00, 1620.50it/s]
#
#  15%|█▌        | 17483/115071 [00:11<01:00, 1607.87it/s]
#
#  15%|█▌        | 17644/115071 [00:11<01:01, 1585.76it/s]
#
#  15%|█▌        | 17809/115071 [00:11<01:00, 1600.37it/s]
#
#  16%|█▌        | 17975/115071 [00:11<01:00, 1615.89it/s]
#
#  16%|█▌        | 18137/115071 [00:11<01:01, 1575.45it/s]
#
#  16%|█▌        | 18295/115071 [00:11<01:01, 1573.89it/s]
#
#  16%|█▌        | 18453/115071 [00:11<01:04, 1489.48it/s]
#
#  16%|█▌        | 18604/115071 [00:12<01:13, 1307.86it/s]
#
#  16%|█▋        | 18740/115071 [00:12<01:19, 1204.35it/s]
#
#  16%|█▋        | 18866/115071 [00:12<01:28, 1093.15it/s]
#
#  16%|█▋        | 18981/115071 [00:12<01:31, 1050.75it/s]
#  55%|█████▌    | 63630/115071 [00:41<00:32, 1564.41it/s]
#
#  55%|█████▌    | 63788/115071 [00:41<00:32, 1567.73it/s]
#
#  56%|█████▌    | 63945/115071 [00:41<00:32, 1557.63it/s]
#
#  56%|█████▌    | 64111/115071 [00:41<00:32, 1584.07it/s]
#
#  56%|█████▌    | 64274/115071 [00:41<00:31, 1596.56it/s]
#
#  56%|█████▌    | 64434/115071 [00:41<00:31, 1583.90it/s]
#
#  56%|█████▌    | 64599/115071 [00:41<00:31, 1599.71it/s]
#
#  56%|█████▋    | 64760/115071 [00:42<00:31, 1595.12it/s]
#
#  56%|█████▋    | 64920/115071 [00:42<00:31, 1573.18it/s]
#
#  57%|█████▋    | 65078/115071 [00:42<00:32, 1535.56it/s]
#
#  57%|█████▋    | 65233/115071 [00:42<00:32, 1535.43it/s]
#
#  57%|█████▋    | 65390/115071 [00:42<00:32, 1544.06it/s]
#
#  57%|█████▋    | 65555/115071 [00:42<00:31, 1571.99it/s]
#
#  57%|█████▋    | 65718/115071 [00:42<00:31, 1588.03it/s]
#
#  57%|█████▋    | 65878/115071 [00:42<00:31, 1577.58it/s]
#
#  57%|█████▋    | 66036/115071 [00:42<00:31, 1571.30it/s]
#
#  58%|█████▊    | 66201/115071 [00:42<00:30, 1593.74it/s]
#
#  58%|█████▊    | 66366/115071 [00:43<00:30, 1610.11it/s]
#
#  58%|█████▊    | 66528/115071 [00:43<00:32, 1511.39it/s]
#
#  58%|█████▊    | 66682/115071 [00:43<00:31, 1519.03it/s]
#
#  58%|█████▊    | 66835/115071 [00:43<00:32, 1501.28it/s]
#
#  58%|█████▊    | 67004/115071 [00:43<00:30, 1551.71it/s]
#
#  58%|█████▊    | 67169/115071 [00:43<00:30, 1578.96it/s]
#
#  59%|█████▊    | 67328/115071 [00:43<00:30, 1562.88it/s]
#
#  59%|█████▊    | 67486/115071 [00:43<00:30, 1567.66it/s]
#
#  59%|█████▉    | 67655/115071 [00:43<00:29, 1599.42it/s]
#
#  59%|█████▉    | 67816/115071 [00:44<00:30, 1557.12it/s]
#
#  59%|█████▉    | 67976/115071 [00:44<00:30, 1568.23it/s]
#
#  59%|█████▉    | 68134/115071 [00:44<00:30, 1540.20it/s]
#
#  59%|█████▉    | 68294/115071 [00:44<00:30, 1556.69it/s]
#
#  59%|█████▉    | 68452/115071 [00:44<00:29, 1561.79it/s]
#
#  60%|█████▉    | 68611/115071 [00:44<00:29, 1567.24it/s]
#
#  60%|█████▉    | 68768/115071 [00:44<00:30, 1506.33it/s]
#
#  60%|█████▉    | 68929/115071 [00:44<00:30, 1535.76it/s]
#
#  60%|██████    | 69090/115071 [00:44<00:29, 1555.76it/s]
#
#  60%|██████    | 69254/115071 [00:44<00:29, 1576.82it/s]
#
#  60%|██████    | 69413/115071 [00:45<00:29, 1566.09it/s]
#
#  60%|██████    | 69580/115071 [00:45<00:28, 1595.44it/s]
#
#  61%|██████    | 69740/115071 [00:45<00:28, 1564.56it/s]
#
#  61%|██████    | 69903/115071 [00:45<00:28, 1583.29it/s]
#
#  88%|████████▊ | 101628/115071 [01:05<00:08, 1634.36it/s]
#
#  88%|████████▊ | 101792/115071 [01:05<00:08, 1591.80it/s]
#
#  89%|████████▊ | 101952/115071 [01:05<00:08, 1565.03it/s]
#
#  89%|████████▊ | 102116/115071 [01:05<00:08, 1584.32it/s]
#
#  89%|████████▉ | 102275/115071 [01:05<00:08, 1568.60it/s]
#
#  89%|████████▉ | 102438/115071 [01:06<00:07, 1586.07it/s]
#
#  89%|████████▉ | 102597/115071 [01:06<00:07, 1578.39it/s]
#
#  89%|████████▉ | 102755/115071 [01:06<00:07, 1573.98it/s]
#
#  89%|████████▉ | 102925/115071 [01:06<00:07, 1609.23it/s]
#
#  90%|████████▉ | 103100/115071 [01:06<00:07, 1646.33it/s]
#
#  90%|████████▉ | 103267/115071 [01:06<00:07, 1649.84it/s]
#
#  90%|████████▉ | 103433/115071 [01:06<00:07, 1634.50it/s]
#
#  90%|█████████ | 103597/115071 [01:06<00:07, 1600.30it/s]
#
#  90%|█████████ | 103758/115071 [01:06<00:07, 1531.20it/s]
#
#  90%|█████████ | 103917/115071 [01:06<00:07, 1546.15it/s]
#
#  90%|█████████ | 104081/115071 [01:07<00:06, 1571.54it/s]
#
#  91%|█████████ | 104243/115071 [01:07<00:06, 1585.50it/s]
#
#  91%|█████████ | 104405/115071 [01:07<00:06, 1593.70it/s]
#
#  91%|█████████ | 104565/115071 [01:07<00:06, 1583.76it/s]
#
#  91%|█████████ | 104724/115071 [01:07<00:06, 1578.41it/s]
#
#  91%|█████████ | 104892/115071 [01:07<00:06, 1607.43it/s]
#
#  91%|█████████▏| 105053/115071 [01:07<00:06, 1604.23it/s]
#
#  91%|█████████▏| 105214/115071 [01:07<00:06, 1572.46it/s]
#
#  92%|█████████▏| 105376/115071 [01:07<00:06, 1581.81it/s]
#
#  92%|█████████▏| 105540/115071 [01:07<00:05, 1595.91it/s]
#
#  92%|█████████▏| 105700/115071 [01:08<00:05, 1574.59it/s]
#
#  92%|█████████▏| 105876/115071 [01:08<00:05, 1625.18it/s]
#
#  92%|█████████▏| 106045/115071 [01:08<00:05, 1641.72it/s]
#
#  92%|█████████▏| 106210/115071 [01:08<00:05, 1633.32it/s]
#
#  92%|█████████▏| 106378/115071 [01:08<00:05, 1644.23it/s]
#
#  93%|█████████▎| 106543/115071 [01:08<00:05, 1599.94it/s]
#
#  93%|█████████▎| 106704/115071 [01:08<00:05, 1584.00it/s]
#
#  93%|█████████▎| 106863/115071 [01:08<00:05, 1522.32it/s]
#
#  93%|█████████▎| 107029/115071 [01:08<00:05, 1556.90it/s]
#
#  93%|█████████▎| 107189/115071 [01:09<00:05, 1567.15it/s]
#
#  93%|█████████▎| 107354/115071 [01:09<00:04, 1589.62it/s]
#
#  93%|█████████▎| 107514/115071 [01:09<00:04, 1586.38it/s]
#
#  94%|█████████▎| 107680/115071 [01:09<00:04, 1605.21it/s]
#
#  94%|█████████▎| 107842/115071 [01:09<00:04, 1609.00it/s]
#
#  94%|█████████▍| 108004/115071 [01:09<00:04, 1583.71it/s]
#
#  94%|█████████▍| 108167/115071 [01:09<00:04, 1596.97it/s]
#
#  94%|█████████▍| 108328/115071 [01:09<00:04, 1598.96it/s]
#
#  94%|█████████▍| 108489/115071 [01:09<00:04, 1546.30it/s]
#
#  94%|█████████▍| 108656/115071 [01:09<00:04, 1579.90it/s]
#
#  95%|█████████▍| 108815/115071 [01:10<00:03, 1573.63it/s]
#
#  95%|█████████▍| 108973/115071 [01:10<00:03, 1558.71it/s]
#
#  95%|█████████▍| 109141/115071 [01:10<00:03, 1591.27it/s]
#
#  95%|█████████▍| 109302/115071 [01:10<00:03, 1595.03it/s]
#
#  95%|█████████▌| 109462/115071 [01:10<00:03, 1554.89it/s]
#
#  95%|█████████▌| 109629/115071 [01:10<00:03, 1586.69it/s]
#
#  95%|█████████▌| 109789/115071 [01:10<00:03, 1583.05it/s]
#
#  96%|█████████▌| 109953/115071 [01:10<00:03, 1599.43it/s]
#
#  96%|█████████▌| 110114/115071 [01:10<00:03, 1567.57it/s]
#
#  96%|█████████▌| 110277/115071 [01:10<00:03, 1584.57it/s]
#
#  96%|█████████▌| 110436/115071 [01:11<00:02, 1583.22it/s]
#
#  96%|█████████▌| 110602/115071 [01:11<00:02, 1605.46it/s]
#
#  96%|█████████▋| 110763/115071 [01:11<00:02, 1519.29it/s]
#
#  96%|█████████▋| 110924/115071 [01:11<00:02, 1545.40it/s]
#
#  97%|█████████▋| 111081/115071 [01:11<00:02, 1551.69it/s]
#
#  97%|█████████▋| 111240/115071 [01:11<00:02, 1562.14it/s]
#
#  97%|█████████▋| 111397/115071 [01:11<00:02, 1463.52it/s]
#
#  97%|█████████▋| 111545/115071 [01:11<00:02, 1461.91it/s]
#
#  97%|█████████▋| 111702/115071 [01:11<00:02, 1490.20it/s]
#
#  97%|█████████▋| 111852/115071 [01:11<00:02, 1489.58it/s]
#
#  97%|█████████▋| 112004/115071 [01:12<00:02, 1493.57it/s]
#
#  97%|█████████▋| 112166/115071 [01:12<00:01, 1526.39it/s]
#
#  98%|█████████▊| 112322/115071 [01:12<00:01, 1533.94it/s]
#
#  98%|█████████▊| 112477/115071 [01:12<00:01, 1536.40it/s]
#
#  98%|█████████▊| 112631/115071 [01:12<00:01, 1535.94it/s]
#
#  98%|█████████▊| 112785/115071 [01:12<00:01, 1535.65it/s]
#
#  98%|█████████▊| 112944/115071 [01:12<00:01, 1549.53it/s]
#
#  98%|█████████▊| 113100/115071 [01:12<00:01, 1514.18it/s]
#
#  98%|█████████▊| 113257/115071 [01:12<00:01, 1527.95it/s]
#
#  99%|█████████▊| 113417/115071 [01:13<00:01, 1545.84it/s]
#
#  99%|█████████▊| 113574/115071 [01:13<00:00, 1551.25it/s]
#
#  99%|█████████▉| 113730/115071 [01:13<00:00, 1551.34it/s]
#
#  99%|█████████▉| 113886/115071 [01:13<00:00, 1553.35it/s]
#
#  99%|█████████▉| 114042/115071 [01:13<00:00, 1552.92it/s]
#
#  99%|█████████▉| 114200/115071 [01:13<00:00, 1557.61it/s]
#
#  99%|█████████▉| 114356/115071 [01:13<00:00, 1548.70it/s]
#
# 100%|█████████▉| 114517/115071 [01:13<00:00, 1565.48it/s]
#
# 100%|█████████▉| 114674/115071 [01:13<00:00, 1545.89it/s]
#
# 100%|█████████▉| 114829/115071 [01:13<00:00, 1528.92it/s]
#
# 100%|██████████| 115071/115071 [01:14<00:00, 1553.14it/s]

# %%
# 태그 없애기
title_khaiii2 = title_khaiii.copy()
for i,title in enumerate(title_khaiii):
    title_khaiii2[i] = [t[0] for t in title]

# %%
train['title2tags'] = title_khaiii

# %%
train[['plylst_title','tags','title2tags']].tail(50)
# Out:
#                                    plylst_title  ...                                         title2tags
# 115021                    커피와 함께 밤에듣는 명품 보이스라떼.  ...    [(커피, NNG), (함께, MAG), (명품, NNG), (보이스라떼, NNG)]
# 115022                           와닿는 가사들, 멜로디..  ...                            [(가사, NNG), (멜로디, NNG)]
# 115023                     귀르가즘 느끼는 노래모음 이어폰 필수  ...    [(귀르가즘, NNG), (모음, NNG), (이어폰, NNG), (필수, NNG)]
# 115024                 [매주 업데이트] 슈가맨 시즌3 슈가송 모음  ...  [(매주, MAG), (업데이트, NNG), (슈가맨, NNP), (시즌, NNG)...
# 115025                      지친 당신에게 위로가 되어줄 노래들  ...                                        [(위로, NNG)]
# 115026                 여유로운 연휴! 개성있는 감성 뮤직과 함께!  ...  [(여유, NNG), (연휴, NNG), (개성, NNG), (감성, NNG), (...
# 115027                            따뜻한 봄을 알리는 음악  ...                                         [(따뜻, XR)]
# 115028                       클럽에서 즐기는 진정한 즐거움!?  ...                  [(클럽, NNG), (진정, XR), (즐거움, NNG)]
# 115029                             우울증 환자 Vol.4  ...                 [(우울증, NNG), (환자, NNG), (Vol, SL)]
# 115030                        취향저격 나만의 팝송 GET!!  ...       [(취향, NNG), (저격, NNG), (팝송, NNG), (GET, SL)]
# 115031                한 방울의 추억 (나의 아름다운 시절은...)  ...                  [(방울, NNG), (추억, NNG), (시절, NNG)]
# 115032                          오마이걸 콘서트 '여름동화'  ...    [(오마이걸, NNP), (콘서트, NNG), (여름, NNG), (동화, NNG)]
# 115033                             RomanticShow  ...                               [(RomanticShow, SL)]
# 115034                         못 들어본 사람은 있어도 16  ...                              [(사람, NNG), (16, SN)]
# 115035     사상 최대 규모의 Tomorrowland 2017이 기대되는 이유  ...  [(사상, NNG), (최대, NNG), (규모, NNG), (Tomorrowlan...
# 115036               3년간 엄선한 EDM 클럽하우스 뮤직 top75  ...  [(엄선, NNG), (EDM, SL), (클럽하우스, NNG), (뮤직, NNG)...
# 115037                         사랑하면 왠지 끌리는 노래？？  ...                             [(사랑, NNG), (왠지, MAG)]
# 115038                             봄 봄 봄이왔어요~~~  ...                                                 []
# 115039                       장르상관없이 본인이 좋아하는노래들  ...       [(장르, NNG), (상관, NNG), (없이, MAG), (본인, NNG)]
# 115040                                섹시 분위기 힙합  ...                            [(분위기, NNG), (힙합, NNG)]
# 115041                     상쾌한 아침과 드라이브, 신나는 노래  ...                 [(상쾌, XR), (아침, NNG), (드라이브, NNG)]
# 115042                                  지선의 재발견  ...                             [(지선, NNG), (발견, NNG)]
# 115043                         흥겨운 빅밴드의 재즈 사운드!  ...                            [(재즈, NNG), (사운드, NNG)]
# 115044                                  행복빵빵뮤직   ...                  [(행복, NNG), (빵빵, NNG), (뮤직, NNG)]
# 115045                                 2020년 1월  ...                                       [(2020, SN)]
# 115046                     크리스마스&겨울에 생각나는 J-pop  ...                       [(크리스마스겨울, NNG), (Jpop, SL)]
# 115047                          댄스그룹이 부른 감미로운 곡  ...                  [(댄스, NNG), (그룹, NNG), (감미, NNG)]
# 115048                                    선아님아1  ...                                      [(선아님아, NNG)]
# 115049                            첫눈처럼 설레였던 그날♥  ...                             [(첫눈, NNG), (그날, NNG)]
# 115050                              힙합과 댄스가 만나면  ...                             [(힙합, NNG), (댄스, NNG)]
# 115051                                   기타선율 팝  ...                             [(기타, NNG), (선율, NNG)]
# 115052              추억의suppe:overture크로스over...  ...  [(추억, NNG), (suppeoverture, SL), (크로스, NNG), (...
# 115053         4.일렉_ComeTogether!!!_custom.GOGR  ...                     [(ComeTogethercustomGOGR, SL)]
# 115054                  들을수록 걸크러쉬 물씬 느껴지는 음악리스트  ...    [(걸크, NNG), (러쉬, NNP), (물씬, MAG), (음악리스트, NNG)]
# 115055                                    12월1일  ...                                         [(12, SN)]
# 115056                   Let's Groove 느낌있는 감성힙합  ...  [(Lets, SL), (Groove, SL), (느낌, NNG), (감성, NNG...
# 115057                           오후의 어쿠스틱 vol.2  ...                [(오후, NNG), (어쿠스틱, NNG), (vol, SL)]
# 115058                                  여자친구 명곡  ...                  [(여자, NNG), (친구, NNG), (명곡, NNG)]
# 115059                              달달한 사탕같은 노래  ...                              [(달달, XR), (사탕, NNG)]
# 115060  #기분업! 에너지필~ 사운드굿! 해외 EDM/일렉 선곡#2019년9월#  ...  [(기분업, NNG), (에너지필, NNG), (사운드굿, NNG), (해외, NN...
# 115061                     카페에서 손님들이 궁금해하는노래^.^  ...                              [(카페, NNG), (궁금, XR)]
# 115062      J pop처음 듣는 사람도 중독된 듯 빠져드는 j pop 리스트  ...  [(pop, SL), (처음, NNG), (사람, NNG), (중독, NNG), (...
# 115063                 들으면 설레는 드라마 및 영화 삽입곡&OST  ...     [(드라마, NNG), (영화, NNG), (삽입곡, NNG), (OST, SL)]
# 115064                    meltedmoon's tastes 1  ...                  [(meltedmoons, SL), (tastes, SL)]
# 115065                                   남자고백노래  ...                                      [(남자고백, NNG)]
# 115066                            METAL E'SM #2  ...                           [(METAL, SL), (ESM, SL)]
# 115067           빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!  ...  [(리스너, NNG), (따끈따끈, MAG), (최신, NNG), (인기, NNG)...
# 115068                    #1. 눈물이 앞을 가리는 나의_이야기  ...                           [(눈물, NNG), (의이야기, NNG)]
# 115069        퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP  ...  [(퇴근, NNG), (버스, NNG), (편히, MAG), (하루, NNG), (...
# 115070                      FAVORITE POPSONG!!!  ...                    [(FAVORITE, SL), (POPSONG, SL)]
#
# [50 rows x 3 columns]

# %%
sum_of_intersect = 0
for i in tqdm(train.index):
    tags = set(train.loc[i]['tags'])
    tags_from_title = set(train.loc[i]['title2tags'])
    sum_of_intersect += len(tags & tags_from_title) / len(tags)
    # if tags & tags_from_title:
    #     print(tags & tags_from_title)
sum_of_intersect / len(train)
# Out:
# 100%|██████████| 115071/115071 [00:55<00:00, 2064.90it/s]
# 0.12910328290574238

# %% [markdown]
# ### 가수 이름 제목에 들어가는지 확인

# %% [markdown]
# ### validation에서 title로 태그 추출

# %%
train['date'] = train['updt_date'].apply(lambda x: int(str(x[2:4]) + str(x[5:7])) )    # 연도+월
train['year'] = train['updt_date'].apply(lambda x: int(x[2:4]))                                    # 연도
val['date'] = val['updt_date'].apply(lambda x: int(str(x[2:4]) + str(x[5:7])) )
val['year'] = val['updt_date'].apply(lambda x: int(x[2:4]))
test['date'] = test['updt_date'].apply(lambda x: int(str(x[2:4]) + str(x[5:7])) )
test['year'] = test['updt_date'].apply(lambda x: int(x[2:4]))


date_list = list(train['date'].unique())
date_list= sorted(date_list)

date_dict = {}       # 해당 연도+월 에 index 부여(?)
for i,k in enumerate(date_list):
    date_dict[k] = i

#### popular monthly tag
popular_date_tag = []
for i in range(len(date_list)):
    ## if 부분 재검토 해보기
    if i <= 13:  ## 13이전에는 한 달에 100개가 안나옴
        year = int(str(date_list[i])[0]) ## year
        tmp = train[train['year'] == year]
        _, year_tag = most_popular(tmp, "tags", 100)
        popular_date_tag.append({
            "date" : date_list[i],
            "tags" : year_tag,})
    else:
        tmp = train[train['date'] == date_list[i]]
        _, date_tag = most_popular(tmp, "tags", 100)
        popular_date_tag.append({
            "date" : date_list[i],
            "tags" : date_tag,})

#### popular monthly song
popular_date_song = []
for i in range(len(date_list)):
    ## if 부분 재검토 해보기
    if i <= 9:  ## 11이전에는 한 달에 100개가 안나옴
        year = int(str(date_list[i])[0]) ## year
        tmp = train[train['year'] == year]
        _, date_song = most_popular(tmp, "songs", 200)
        popular_date_song.append({
            "date" : date_list[i],
            "songs" : date_song,})               
    else:
        tmp = train[train['date'] == date_list[i]]
        _, date_song = most_popular(tmp, "songs", 200)
        popular_date_song.append({
            "date" : date_list[i],
            "songs" : date_song,})

# %%
def add_tags(data):
    title_khaiii = do_khaiii_col(data['plylst_title'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]"," "))
    title_khaiii2 = ['']*len(data)
    for i,title in enumerate(tqdm(title_khaiii)):
        title_khaiii2[i] = [t[0] for t in title]
    data['tags_new'] = data['tags'] + title_khaiii2
    tn_list = []
    for tn in tqdm(data['tags_new']):
        tn_list.append(list(set(tn)))
    data['tags_new'] = tn_list
    return data

# %%
no_tag, no_song, yes_index, no_both = check_target_type(val)
# Out:
# 노래 O 태그 X : 9661개
# 노래 X 태그 O : 2630개
# 노래 O 태그 O : 8975개
# 노래 X 태그 X : 1749개

# %%
val1 = val[val.index.isin(no_tag)]
val2 = val[val.index.isin(no_song)]
val3 = val[val.index.isin(yes_index)]
val4 = val[val.index.isin(no_both)]

print(len(val1[val1['plylst_title']!='']))
print(len(val2[val2['plylst_title']!='']))
print(len(val3[val3['plylst_title']!='']))
print(len(val4[val4['plylst_title']!='']))
# Out:
# 0
# 2628
# 0
# 1745

# %%
# val2, 4에만 제목 존재
val2 = val[val.index.isin(no_song)]
val4 = val[val.index.isin(no_both)]

# %%
len(val2[val2['plylst_title']!=''])
# Out:
# 2628

# %%
val2_new = add_tags(val2)
val4_new = add_tags(val4)
# Out:
# 100%|██████████| 2630/2630 [00:01<00:00, 1812.87it/s]
# 100%|██████████| 2630/2630 [00:00<00:00, 433643.35it/s]
# 100%|██████████| 2630/2630 [00:00<00:00, 401756.18it/s]
# 100%|██████████| 1749/1749 [00:00<00:00, 2067.72it/s]
# 100%|██████████| 1749/1749 [00:00<00:00, 425389.25it/s]
# 100%|██████████| 1749/1749 [00:00<00:00, 620052.21it/s]

# %%
val2_new.head()
# Out:
#                        tags  ...                                       tags_new
# 8                    [스트레스]  ...                                     [스트레스, 운동]
# 17                    [생각나]  ...                                  [생각나, 다시, 사람]
# 20          [피아노, 이루마, 메로디]  ...                  [메로디, 뉴에이, 피아노, 불면증, 곡들, 이루마]
# 40  [발렌타인데이, 달달한, 사랑노래, 고백]  ...  [발렌타, 초콜릿, 달달한, 발렌타인데이, 매장, 데이, 사랑노래, 달콤, 고백]
# 42                     [새벽]  ...                               [기분, 하루, 새벽, 잔잔]
#
# [5 rows x 9 columns]

# %%
val4_new.head()
# Out:
#    tags      id             plylst_title  ...  date  year          tags_new
# 1    []  131447                   앨리스테이블  ...  1407    14        [이블, 앨리스테]
# 9    []  142007  기분 좋은 재즈와 함께 만드는 달달한 하루  ...  1506    15  [기분, 함께, 재즈, 하루]
# 35   []   65114       ■■■■ 사랑,그리고이별 ■■■■  ...  1010    10          [사랑, 이별]
# 57   []   87700          마쉬멜로우같은 멜로우한 음악  ...  1601    16    [마쉬, 멜로우한, 멜로]
# 71   []   35271       공부와 독서를 위한 #Newage  ...  2001    20          [공부, 독서]
#
# [5 rows x 9 columns]

# %%
list(set(val2_new.loc[8]['tags_new']) - set(val2_new.loc[8]['tags']))
# Out:
# ['운동']

# %% [markdown]
# ---

# %% [markdown]
# ### val2 예측

# %%
val2_predict = []
for i in tqdm(val2.index):
    date = date_dict[val2.loc[i]['date']]
    #####  song 채우기
    song_counter = Counter()
    for tag in val2.loc[i]['tags']:
        if str(tag) in tag_song_dict:
            for song in tag_song_dict[str(tag)]:
                song_counter.update({song : 1})
    song_counter = sorted(song_counter.items(), key= lambda x:x[1], reverse = True)        
    cur_song = []
    for k in song_counter[:100]:
        cur_song.append(k[0])
    if len(cur_song) == 0:
        cur_song = popular_date_song[date]['songs'][:100]
    elif len(cur_song) < 100:
        update_song = remove_seen(cur_song, popular_date_song[date]['songs'])
        cur_song.extend(update_song)
        cur_song = cur_song[:100]
    ##### tag 채우기
    tag_counter = Counter()
    for song in cur_song[:10]:
        if str(song) in song_tag_dict:
            for tag in song_tag_dict[str(song)]:
                tag_counter.update({tag : 1})
    tag_counter = sorted(tag_counter.items(), key= lambda x:x[1], reverse = True)        
    tag_counter = tag_counter[:100] ## 넉넉히 100개 잡는다. 
    cur_tag = list(set(val2_new.loc[i]['tags_new']) - set(val2_new.loc[i]['tags']))
    # cur_tag = []
    for k in tag_counter:
        if k[0] not in cur_tag:
            cur_tag.append(k[0])     
    if len(cur_tag) == 0:
        cur_tag = popular_date_tag[date]['tags'][:100]
    elif len(cur_tag) < 100:
        update_tag = remove_seen(cur_tag, popular_date_tag[date]['tags'])
        update_tag = [u for u in update_tag if u not in cur_tag]
        cur_tag.extend(update_tag)
        cur_tag = cur_tag[:100]

    val2_predict.append({
        "id" : list(val2.loc[i:i, 'id'])[0],
        "songs": cur_song,
        "tags": remove_seen(val2.loc[i]['tags'], cur_tag)[:10],
    })

write_json(val2_predict, data_path+'results/val/val2_predict_withTitle.json')

# %%
val4_predict = []

for i in tqdm(val4.index):
    date = date_dict[val4.loc[i]['date']]
    cur_tag = list(set(val4_new.loc[i]['tags_new']) - set(val4_new.loc[i]['tags']))
    #####  song 채우기
    song_counter = Counter()
    for tag in cur_tag[:10]:
        if str(tag) in tag_song_dict:
            for song in tag_song_dict[str(tag)]:
                song_counter.update({song : 1})
    song_counter = sorted(song_counter.items(), key= lambda x:x[1], reverse = True)        
    cur_song = []
    for k in song_counter[:100]:
        cur_song.append(k[0])
    if len(cur_song) == 0:
        cur_song = popular_date_song[date]['songs'][:100]
    elif len(cur_song) < 100:
        update_song = remove_seen(cur_song, popular_date_song[date]['songs'])
        cur_song.extend(update_song)
        cur_song = cur_song[:100]
    ##### tag 채우기
    tag_counter = Counter()
    for song in cur_song[:10]:
        if str(song) in song_tag_dict:
            for tag in song_tag_dict[str(song)]:
                tag_counter.update({tag : 1})
    tag_counter = sorted(tag_counter.items(), key= lambda x:x[1], reverse = True)        
    tag_counter = tag_counter[:100] ## 넉넉히 100개 잡는다. 
    for k in tag_counter:
        if k[0] not in cur_tag:
            cur_tag.append(k[0])     
    if len(cur_tag) == 0:
        cur_tag = popular_date_tag[date]['tags'][:100]
    elif len(cur_tag) < 100:
        update_tag = remove_seen(cur_tag, popular_date_tag[date]['tags'])
        update_tag = [u for u in update_tag if u not in cur_tag]
        cur_tag.extend(update_tag)
        cur_tag = cur_tag[:100]

    val4_predict.append({
        "id" : val4.loc[i]['id'],
        "songs": cur_song,
        "tags": remove_seen(val4.loc[i]['tags'], cur_tag)[:10],
    })

# %%
def write_json16(data, fname):
    # json 저장하기
    def _conv(o):
        if isinstance(o, (np.int64, np.int32)):
            return int(o)
        raise TypeError
    parent = os.path.dirname(fname)
    distutils.dir_util.mkpath(parent)
    with io.open(fname, "w", encoding="utf-16") as f:
        json_str = json.dumps(data, ensure_ascii=False, default=_conv)
        f.write(json_str)

write_json16(val4_predict, data_path+'val4_predict_withTitle.json')
